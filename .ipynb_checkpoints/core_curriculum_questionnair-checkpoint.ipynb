# %% [markdown]
# # questionnair

# %%
# %load_ext autoreload 
# %autoreload 2

import sys
sys.path.append("../public/")
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# custom func.
import pathList as pL
import dataEngineer as dE
import question as qu
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# -----------------------------------------------------------------------
# ModuleNotFoundError                   Traceback (most recent call last)
# <ipython-input-9-50750573c2f3> in <module>()
#      12 import pathList as pL
#      13 import dataEngineer as dE
# ---> 14 import question as qu
#
# ModuleNotFoundError: No module named 'question'

# %%
file = "../dt/core_questionnaire.xlsx"
x1 = pd.ExcelFile(file) 
print(x1.sheet_names) 
df = x1.parse("Sheet1") 
df.head().T
# Out:
# ['Sheet1']
#                                                                                                     0  \
# タイムスタンプ                                                                    2019-10-10 11:11:16.389000
# 診療科                                                                                           内科(大学内)
# 病院・グループ名(内科の場合は診療科の記載もお願いします。)　　　　　例：市立札幌病院　呼吸器...                                             北大神経内科
# 病院を選んだ理由(複数選択可)                                                                             抽選に外れ仕方なく
# 拘束時間(例 9:00～17:00)                                                                         8:00∼17:10
# 実習中の忙しさ                                                                                             2
# 1日のスケジュール(できれば曜日毎)                                  朝の回診が8:30よりあるのでそれに参加し、その後検査などを見学する。11:30~14:00...
# 実習中空き時間はつくれたか                                                                    回診以外の時間はいなくても可。PHS有。
# 実習における必須課題                                                                             毎週総回診での発表、最終発表
# 指導医(研修医)の人数、面倒見の良さ                                                                              5人、放置
# 昼食事情について                                                                                    各自。火曜のみ弁当
# 病院の設備や綺麗さ、カルテについて                                                                              北大に準ずる
# 学生用の机、Wi-Fi、ロッカーの有無                                         wi-fiはあるが、担当の先生に認証するプロセスがある。机とカルテは一部を陣取る。
# 病院までのアクセス                                                                                      北大に準ずる
# (遠隔地のみ)宿舎の様子・街について                                                                                NaN
# 病院に関するフリーコメント                                                                                     NaN
# その他特記事項・メッセージ                                       スキマ時間をつぶすアイテムが必須。あとはタイピングがやたら早くなるので、練習したい人にはうっ...
#
#                                                                                                     1  \
# タイムスタンプ                                                                    2019-10-10 11:31:22.420000
# 診療科                                                                                           内科(大学内)
# 病院・グループ名(内科の場合は診療科の記載もお願いします。)　　　　　例：市立札幌病院　呼吸器...                                           北大  神経内科
# 病院を選んだ理由(複数選択可)                                                                             抽選に外れ仕方なく
# 拘束時間(例 9:00～17:00)                                                      8:30(火曜は8時)〜17:00 (基本17時は過ぎる)
# 実習中の忙しさ                                                                                             5
# 1日のスケジュール(できれば曜日毎)                                  毎週新たに入院してくる患者さんを1人持ち、その患者さんの問診、診察、検査、ICがあれば担当医...
# 実習中空き時間はつくれたか                                           11:30〜14:00は昼休み。担当患者の都合次第では昼休み中でもPHSで呼ばれることも。
# 実習における必須課題                                          総回診時の患者紹介プレゼン。4週目の最終日に担当した症例から一例選び、総回診時のプレゼン+そ...
# 指導医(研修医)の人数、面倒見の良さ                                                             病棟には4人ほど先生がいてどの先生も優しい。
# 昼食事情について                                                                             火曜に薬説があり弁当がもらえる。
# 病院の設備や綺麗さ、カルテについて                                                                                 NaN
# 学生用の机、Wi-Fi、ロッカーの有無                                         病棟の先生の数が少ないので机は割当たる。Wi-Fiは先生に言えば使わせてもらえる。
# 病院までのアクセス                                                                                         NaN
# (遠隔地のみ)宿舎の様子・街について                                                                                NaN
# 病院に関するフリーコメント                                                                                     NaN
# その他特記事項・メッセージ                                             学内内科の中では忙しい方なので楽したい方やバイトがあり17時前には帰りたい方は別の科へ
#
#                                                                                                     2  \
# タイムスタンプ                                                                    2019-10-10 12:11:53.525000
# 診療科                                                                                           内科(大学内)
# 病院・グループ名(内科の場合は診療科の記載もお願いします。)　　　　　例：市立札幌病院　呼吸器...                                         第二内科、腎グループ
# 病院を選んだ理由(複数選択可)                                                       診療科に興味があった, ゆるそうだから, 立地・アクセスが良い
# 拘束時間(例 9:00～17:00)                                                                     8:30〜9:30（最短で）
# 実習中の忙しさ                                                                                             3
# 1日のスケジュール(できれば曜日毎)                                  毎日8:30から朝回診。月曜午後から総回診。火、木曜13:30から腎生検、火曜16:00から...
# 実習中空き時間はつくれたか                                       上に書いたスケジュール以外は完全にフリー。回診終わったらもうやることないから帰っていいよと言...
# 実習における必須課題                                                                              A3レポート一枚とその発表
# 指導医(研修医)の人数、面倒見の良さ                                            どのスタッフも忙しく基本的に放置気味だが、質問すれば優しく丁寧に教えてくれる。
# 昼食事情について                                                                         昼までCRに残ってると必ずおごってくれる
# 病院の設備や綺麗さ、カルテについて                                                                          CRの人工密度は高め
# 学生用の机、Wi-Fi、ロッカーの有無                                                                       CRのWiFiは使用可
# 病院までのアクセス                                                                                         NaN
# (遠隔地のみ)宿舎の様子・街について                                                                                NaN
# 病院に関するフリーコメント                                                                                     NaN
# その他特記事項・メッセージ                                       朝回診のあと一度開放されるので、午前中にたくさん空き時間を作れる。腎生検も、自分は実施された...
#
#                                                                                                     3  \
# タイムスタンプ                                                                    2019-10-10 12:35:17.563000
# 診療科                                                                                           内科(大学内)
# 病院・グループ名(内科の場合は診療科の記載もお願いします。)　　　　　例：市立札幌病院　呼吸器...                                         循環器内科Aグループ
# 病院を選んだ理由(複数選択可)                                                                               ゆるそうだから
# 拘束時間(例 9:00～17:00)                                                                         9:00-10:00
# 実習中の忙しさ                                                                                             1
# 1日のスケジュール(できれば曜日毎)                                  火曜日は8:00から1、2時間のカンファと総回診があり、終わり次第カルテ記載。\n火曜日以外...
# 実習中空き時間はつくれたか                                                                         空き時間はないが速攻で帰れる。
# 実習における必須課題                                                                          A41枚のレポート(感想書くだけ)
# 指導医(研修医)の人数、面倒見の良さ                                  指導医の人数は各チーム2、3人ほど。\n研修医は1人。\n基本放置だが質問したり指導を仰げば...
# 昼食事情について                                                                               お昼前に帰れるので特にない。
# 病院の設備や綺麗さ、カルテについて                                                                                 NaN
# 学生用の机、Wi-Fi、ロッカーの有無                                                                               NaN
# 病院までのアクセス                                                                                         NaN
# (遠隔地のみ)宿舎の様子・街について                                                                                NaN
# 病院に関するフリーコメント                                                                                     NaN
# その他特記事項・メッセージ                                                                                選んでよかった！
#
#                                                                                                 4
# タイムスタンプ                                                                2019-10-10 12:40:21.074000
# 診療科                                                                                       内科(大学内)
# 病院・グループ名(内科の場合は診療科の記載もお願いします。)　　　　　例：市立札幌病院　呼吸器...                                      血液内科2グループ
# 病院を選んだ理由(複数選択可)                                                               診療科に興味があった, ゆるそうだから
# 拘束時間(例 9:00～17:00)                                                            8:55〜10:00＋週二でレクチャー
# 実習中の忙しさ                                                                                         2
# 1日のスケジュール(できれば曜日毎)                                  毎日朝回診9時から\n終わり次第カルテを書き、終了。\nレクチャーは週二である、一回一時間
# 実習中空き時間はつくれたか                                                                            めっちゃ作れます
# 実習における必須課題                                                                                 症例レポート
# 指導医(研修医)の人数、面倒見の良さ                                                                        優しかったです
# 昼食事情について                                                                     一緒に食べに行ったことは一回もありません
# 病院の設備や綺麗さ、カルテについて                                                                     北大なのでぼちぼちです
# 学生用の机、Wi-Fi、ロッカーの有無                                     CRは狭いので机はあたりません。学生自習室があるのでそっちにいったりもしてました。
# 病院までのアクセス                                                                                     NaN
# (遠隔地のみ)宿舎の様子・街について                                                                            NaN
# 病院に関するフリーコメント                                                                                 NaN
# その他特記事項・メッセージ                                                                            めっちゃ楽です。

# %%
dfKey = {}
for i,k in enumerate(df.keys()):
    dfKey[i] = k
dfKey
# Out:
# {0: 'タイムスタンプ',
#  1: '診療科',
#  2: '病院・グループ名(内科の場合は診療科の記載もお願いします。)\u3000\u3000\u3000\u3000\u3000例：市立札幌病院\u3000呼吸器内科、北大\u3000第一外科\u3000小児外科グループ',
#  3: '病院を選んだ理由(複数選択可)',
#  4: '拘束時間(例 9:00～17:00)',
#  5: '実習中の忙しさ',
#  6: '1日のスケジュール(できれば曜日毎)',
#  7: '実習中空き時間はつくれたか',
#  8: '実習における必須課題',
#  9: '指導医(研修医)の人数、面倒見の良さ',
#  10: '昼食事情について',
#  11: '病院の設備や綺麗さ、カルテについて',
#  12: '学生用の机、Wi-Fi、ロッカーの有無',
#  13: '病院までのアクセス',
#  14: '(遠隔地のみ)宿舎の様子・街について',
#  15: '病院に関するフリーコメント',
#  16: 'その他特記事項・メッセージ'}

# %%
df.loc[:,[dfKey[2],dfKey[4]]]
# Out:
#     病院・グループ名(内科の場合は診療科の記載もお願いします。)　　　　　例：市立札幌病院　呼吸器内科、北大　第一外科　小児外科グループ  \
# 0                                               北大神経内科
# 1                                             北大  神経内科
# 2                                           第二内科、腎グループ
# 3                                           循環器内科Aグループ
# 4                                            血液内科2グループ
# 5                                          循環器内科　Bグループ
# 6                                              北大 神経内科
# 7                                              北大 神経内科
# 8                                                 第一内科
# 9                                          血液内科（1グループ）
# 10                                         第一内科　非癌グループ
# 11                                      消化器内科　化学療法グループ
# 12                                  北海道大学　消化器内科　胆膵グループ
# 13                                    北大 消化器内科 内視鏡グループ
# 14                                             北大　第二内科
# 15                                              北大血液内科
# 16                                       北大消化器内科胆膵グループ
# 17                                北大 第II内科 糖尿病•内分泌グループ
# 18                                           北大内科１ 癌Gr
# 19                                                第一内科
# 20                                         第二内科　腎臓グループ
# 21                                        北大　1内　非癌グループ
# 22                                        北大第一内科（循環代謝）
# 23                                                  北大
# 24                                           第一内科  肺癌G
# 25                                        北大　血液内科2グループ
# 26                                         循環器内科　Bグループ
# 27                                             北大　神経内科
# 28                                                神経内科
# 29                                          北大消化器内科肝臓G
# ..                                                 ...
# 185                                    北大 第一外科 肝胆膵グループ
# 186                                           市立釧路総合病院
# 187                                               斗南病院
# 188                                          手稲渓仁会病院外科
# 189                                          札幌北楡病院 外科
# 190                                           北大　循環器外科
# 191                                    北大第一外科　小児外科グループ
# 192                                         国立病院機構函館病院
# 193                                           北大 呼吸器外科
# 194                                               天使病院
# 195                                            北大 第一外科
# 196                                          市立稚内病院　外科
# 197                                          王子総合病院　外科
# 198                                     北大　第一外科　移植グループ
# 199                                   北大病院　第一外科　肝臓グループ
# 200                                        北海道大学 呼吸器外科
# 201                                               天使病院
# 202                                             小樽協会病院
# 203                                               天使病院
# 204                                         KKR札幌病院 外科
# 205                                           私立稚内病院外科
# 206                                           北大　呼吸器外科
# 207                                       消化器外科Ⅱ　Bグループ
# 208                                             函館中央病院
# 209                                               国立函館
# 210                                             函館中央病院
# 211                                       恵佑会札幌　大腸グループ
# 212                                           市立釧路総合病院
# 213                                            北見赤十字病院
# 214                                    北大　第一外科　肝胆膵グループ
#
#                    拘束時間(例 9:00～17:00)
# 0                          8:00∼17:10
# 1       8:30(火曜は8時)〜17:00 (基本17時は過ぎる)
# 2                      8:30〜9:30（最短で）
# 3                          9:00-10:00
# 4                 8:55〜10:00＋週二でレクチャー
# 5             8:30～10:00(9割方。検査がなければ)
# 6    月水木金 8.5-11 14-17   火 8-11 14-17
# 7    月水木金 8.5-11 14-17   火 8-11 14-17
# 8                          9:00〜16:00
# 9                          8:30〜15:00
# 10    1日の平均拘束時間は最大で3時間ほど(総回診のある水曜を除く)
# 11                         8:30〜10:00
# 12                         9:00〜17:00
# 13            9時〜17時（5〜10分遅くてもいいとのこと）
# 14                          8:45-9:30
# 15                         9:00〜14:00
# 16             9:00～17:00（火曜日のみ7:30～）
# 17                         8:30-17:00
# 18                         9:00～16:30
# 19            9:00-11:30, 16:00-16:30
# 20                         8:30-14:30
# 21                         9:00-16:30
# 22                         9:00~15:00
# 23                          0930〜1230
# 24                         9:00~17:00
# 25                         9:00-14:00
# 26                          8:30〜9:30
# 27                         8:30～17:00
# 28                          0830~1700
# 29                         9：00〜17：00
# ..                                ...
# 185                        7:30〜15:00
# 186                        8:30〜17:00
# 187               8:30～17:15(火曜日は８時～)
# 188                        8:30~17:00
# 189                        8:30-16:00
# 190                        8:00〜16:00
# 191                 7:30から16:30〜18:00
# 192                        8:30～17:00
# 193                            9時〜14時
# 194                        8:30-16:00
# 195                        7:30-15:00
# 196                        8:30〜17:00
# 197        7:50〜17:00 水曜日だけ7:30〜17:30
# 198                        7:30~12:00
# 199                        7:30〜12:00
# 200                        8:30〜12:00
# 201                      8:30〜手術終わるまで
# 202                        8:00〜16:50
# 203                        8:30-16:00
# 204                        8:30-16:30
# 205                        8:30-17:00
# 206                        8:30〜12:00
# 207                        8:30～16:30
# 208                        8:30〜17:00
# 209                        8:30～17:00
# 210                        8:30〜16:30
# 211                        7:40〜18:00
# 212                        8:30〜17:00
# 213                        9:00～16:30
# 214                        7:30〜16:00
#
# [215 rows x 2 columns]

# %%
qu.showItems(df,dfKey[4],dfKey,regions)
# Out:
# -----------------------------------------------------------------------
# NameError                             Traceback (most recent call last)
# <ipython-input-8-1f1e3f76a2a4> in <module>()
# ----> 1 qu.showItems(df,dfKey[4],dfKey,regions)
#
# NameError: name 'qu' is not defined
